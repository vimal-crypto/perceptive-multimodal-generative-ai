# %% [markdown]
# # 🦸 Comic Generation Demo
# Generates a multi-panel comic strip using Stable Diffusion + PersonaGPT (DialoGPT).

# %%
import sys
sys.path.append('../src/pmg1/comic_generation')
from comic_generator_logic import generate_comic

story_prompt = 'A superhero saves a city from a giant robot'
output_path = generate_comic(story_prompt, num_panels=4)
print(f'Comic saved to: {output_path}')

# %%
from PIL import Image
import matplotlib.pyplot as plt

comic = Image.open(output_path)
plt.figure(figsize=(20, 5))
plt.imshow(comic)
plt.axis('off')
plt.title('Generated Comic Strip')
plt.show()
